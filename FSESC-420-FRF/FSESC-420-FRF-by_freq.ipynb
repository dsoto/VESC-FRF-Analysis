# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')
import vesc_frf as vf

# %%
data_directories = ['Q-V-RL5A-10kHz',
                    'Q-V-RL5A-20kHz',
                    'Q-V-RL5A-30kHz',
                    'Q-V-RL5A-40kHz',
                    'Q-V-RL5A-50kHz']

for data_directory in data_directories:
    vf.data_report(vf.get_file_list(data_directory))
    print()
# Out:
# Q-V-RL5A-10kHz/frf.1640556189639.csv | 5.00e+03 Hz | len 2047 | gap NA
# Q-V-RL5A-10kHz/frf.1640556190206.csv | 5.00e+03 Hz | len 2047 | gap 567
# Q-V-RL5A-10kHz/frf.1640556190751.csv | 5.00e+03 Hz | len 2047 | gap 545
# Q-V-RL5A-10kHz/frf.1640556191288.csv | 5.00e+03 Hz | len 2047 | gap 537
# Q-V-RL5A-10kHz/frf.1640556191870.csv | 5.00e+03 Hz | len 2047 | gap 582
# Q-V-RL5A-10kHz/frf.1640556192415.csv | 5.00e+03 Hz | len 2047 | gap 545
# Q-V-RL5A-10kHz/frf.1640556192953.csv | 5.00e+03 Hz | len 2047 | gap 538
# Q-V-RL5A-10kHz/frf.1640556193489.csv | 5.00e+03 Hz | len 2047 | gap 536
# Q-V-RL5A-10kHz/frf.1640556194030.csv | 5.00e+03 Hz | len 2047 | gap 541
# Q-V-RL5A-10kHz/frf.1640556194569.csv | 5.00e+03 Hz | len 2047 | gap 539
#
# Q-V-RL5A-20kHz/frf.1640556386266.csv | 1.00e+04 Hz | len 2047 | gap NA
# Q-V-RL5A-20kHz/frf.1640556386689.csv | 1.00e+04 Hz | len 2047 | gap 423
# Q-V-RL5A-20kHz/frf.1640556387101.csv | 1.00e+04 Hz | len 2047 | gap 412
# Q-V-RL5A-20kHz/frf.1640556387514.csv | 1.00e+04 Hz | len 2047 | gap 413
# Q-V-RL5A-20kHz/frf.1640556387933.csv | 1.00e+04 Hz | len 2047 | gap 419
# Q-V-RL5A-20kHz/frf.1640556388381.csv | 1.00e+04 Hz | len 2047 | gap 448
# Q-V-RL5A-20kHz/frf.1640556388819.csv | 1.00e+04 Hz | len 2047 | gap 438
# Q-V-RL5A-20kHz/frf.1640556389268.csv | 1.00e+04 Hz | len 2047 | gap 449
# Q-V-RL5A-20kHz/frf.1640556389690.csv | 1.00e+04 Hz | len 2047 | gap 422
# Q-V-RL5A-20kHz/frf.1640556390111.csv | 1.00e+04 Hz | len 2047 | gap 421
#
# Q-V-RL5A-30kHz/frf.1640556478818.csv | 1.49e+04 Hz | len 2047 | gap NA
# Q-V-RL5A-30kHz/frf.1640556479271.csv | 1.49e+04 Hz | len 2047 | gap 453
# Q-V-RL5A-30kHz/frf.1640556479751.csv | 1.49e+04 Hz | len 2047 | gap 480
# Q-V-RL5A-30kHz/frf.1640556480232.csv | 1.49e+04 Hz | len 2047 | gap 481
# Q-V-RL5A-30kHz/frf.1640556480705.csv | 1.49e+04 Hz | len 2047 | gap 473
# Q-V-RL5A-30kHz/frf.1640556481180.csv | 1.49e+04 Hz | len 2047 | gap 475
# Q-V-RL5A-30kHz/frf.1640556481661.csv | 1.49e+04 Hz | len 2047 | gap 481
# Q-V-RL5A-30kHz/frf.1640556482115.csv | 1.49e+04 Hz | len 2047 | gap 454
# Q-V-RL5A-30kHz/frf.1640556482600.csv | 1.49e+04 Hz | len 2047 | gap 485
# Q-V-RL5A-30kHz/frf.1640556483089.csv | 1.49e+04 Hz | len 2047 | gap 489
#
# Q-V-RL5A-40kHz/frf.1640556528650.csv | 2.00e+04 Hz | len 2047 | gap NA
# Q-V-RL5A-40kHz/frf.1640556529412.csv | 2.00e+04 Hz | len 2047 | gap 762
# Q-V-RL5A-40kHz/frf.1640556530176.csv | 2.00e+04 Hz | len 2047 | gap 764
# Q-V-RL5A-40kHz/frf.1640556530909.csv | 2.00e+04 Hz | len 2047 | gap 733
# Q-V-RL5A-40kHz/frf.1640556531671.csv | 2.00e+04 Hz | len 2047 | gap 762
# Q-V-RL5A-40kHz/frf.1640556532427.csv | 2.00e+04 Hz | len 2047 | gap 756
# Q-V-RL5A-40kHz/frf.1640556533189.csv | 2.00e+04 Hz | len 2047 | gap 762
# Q-V-RL5A-40kHz/frf.1640556533918.csv | 2.00e+04 Hz | len 2047 | gap 729
# Q-V-RL5A-40kHz/frf.1640556534681.csv | 2.00e+04 Hz | len 2047 | gap 763
# Q-V-RL5A-40kHz/frf.1640556535443.csv | 2.00e+04 Hz | len 2047 | gap 762
#
# Q-V-RL5A-50kHz/frf.1640556730496.csv | 2.50e+04 Hz | len 2047 | gap NA
# Q-V-RL5A-50kHz/frf.1640556733715.csv | 2.50e+04 Hz | len 2047 | gap 3219
# Q-V-RL5A-50kHz/frf.1640556737024.csv | 2.50e+04 Hz | len 2047 | gap 3309
# Q-V-RL5A-50kHz/frf.1640556740227.csv | 2.50e+04 Hz | len 2047 | gap 3203
# Q-V-RL5A-50kHz/frf.1640556743427.csv | 2.50e+04 Hz | len 2047 | gap 3200
# Q-V-RL5A-50kHz/frf.1640556746707.csv | 2.50e+04 Hz | len 2047 | gap 3280
# Q-V-RL5A-50kHz/frf.1640556749934.csv | 2.50e+04 Hz | len 2047 | gap 3227
# Q-V-RL5A-50kHz/frf.1640556753095.csv | 2.50e+04 Hz | len 2047 | gap 3161
# Q-V-RL5A-50kHz/frf.1640556756339.csv | 2.50e+04 Hz | len 2047 | gap 3244
# Q-V-RL5A-50kHz/frf.1640556758605.csv | 2.50e+04 Hz | len 2047 | gap 2266

# %%
for data_directory in data_directories:
    vf.plot_plant(data_directory, R=110E-3, L=120E-6, 
                  mag_label='measured', plot_phase=False,
                  title=data_directory)
