# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')
import vesc_frf as vf

# %%
data_directories = ['Q-V-RL5A-10kHz',
                    'Q-V-RL5A-20kHz',
                    'Q-V-RL5A-30kHz',
                    'Q-V-RL5A-40kHz',
                    'Q-V-RL5A-50kHz']

for data_directory in data_directories:
    vf.data_report(vf.get_file_list(data_directory))
    print()
# Out:
# Q-V-RL5A-10kHz/frf.1640559794130.csv | 5.00e+03 Hz | len 2047 | gap NA
# Q-V-RL5A-10kHz/frf.1640559794704.csv | 5.00e+03 Hz | len 2047 | gap 574
# Q-V-RL5A-10kHz/frf.1640559795253.csv | 5.00e+03 Hz | len 2047 | gap 549
# Q-V-RL5A-10kHz/frf.1640559795801.csv | 5.00e+03 Hz | len 2047 | gap 548
# Q-V-RL5A-10kHz/frf.1640559796388.csv | 5.00e+03 Hz | len 2047 | gap 587
# Q-V-RL5A-10kHz/frf.1640559796951.csv | 5.00e+03 Hz | len 2047 | gap 563
# Q-V-RL5A-10kHz/frf.1640559797521.csv | 5.00e+03 Hz | len 2047 | gap 570
# Q-V-RL5A-10kHz/frf.1640559798067.csv | 5.00e+03 Hz | len 2047 | gap 546
# Q-V-RL5A-10kHz/frf.1640559798609.csv | 5.00e+03 Hz | len 2047 | gap 542
# Q-V-RL5A-10kHz/frf.1640559799155.csv | 5.00e+03 Hz | len 2047 | gap 546
#
# Q-V-RL5A-20kHz/frf.1640559853096.csv | 1.00e+04 Hz | len 2047 | gap NA
# Q-V-RL5A-20kHz/frf.1640559853509.csv | 1.00e+04 Hz | len 2047 | gap 413
# Q-V-RL5A-20kHz/frf.1640559853921.csv | 1.00e+04 Hz | len 2047 | gap 412
# Q-V-RL5A-20kHz/frf.1640559854335.csv | 1.00e+04 Hz | len 2047 | gap 414
# Q-V-RL5A-20kHz/frf.1640559854748.csv | 1.00e+04 Hz | len 2047 | gap 413
# Q-V-RL5A-20kHz/frf.1640559855229.csv | 1.00e+04 Hz | len 2047 | gap 481
# Q-V-RL5A-20kHz/frf.1640559855634.csv | 1.00e+04 Hz | len 2047 | gap 405
# Q-V-RL5A-20kHz/frf.1640559856046.csv | 1.00e+04 Hz | len 2047 | gap 412
# Q-V-RL5A-20kHz/frf.1640559856483.csv | 1.00e+04 Hz | len 2047 | gap 437
# Q-V-RL5A-20kHz/frf.1640559856910.csv | 1.00e+04 Hz | len 2047 | gap 427
#
# Q-V-RL5A-30kHz/frf.1640559900330.csv | 1.49e+04 Hz | len 2047 | gap NA
# Q-V-RL5A-30kHz/frf.1640559900798.csv | 1.49e+04 Hz | len 2047 | gap 468
# Q-V-RL5A-30kHz/frf.1640559901256.csv | 1.49e+04 Hz | len 2047 | gap 458
# Q-V-RL5A-30kHz/frf.1640559901734.csv | 1.49e+04 Hz | len 2047 | gap 478
# Q-V-RL5A-30kHz/frf.1640559902224.csv | 1.49e+04 Hz | len 2047 | gap 490
# Q-V-RL5A-30kHz/frf.1640559902664.csv | 1.49e+04 Hz | len 2047 | gap 440
# Q-V-RL5A-30kHz/frf.1640559903108.csv | 1.49e+04 Hz | len 2047 | gap 444
# Q-V-RL5A-30kHz/frf.1640559903574.csv | 1.49e+04 Hz | len 2047 | gap 466
# Q-V-RL5A-30kHz/frf.1640559904048.csv | 1.49e+04 Hz | len 2047 | gap 474
# Q-V-RL5A-30kHz/frf.1640559904502.csv | 1.49e+04 Hz | len 2047 | gap 454
#
# Q-V-RL5A-40kHz/frf.1640559937015.csv | 2.00e+04 Hz | len 2047 | gap NA
# Q-V-RL5A-40kHz/frf.1640559937825.csv | 2.00e+04 Hz | len 2047 | gap 810
# Q-V-RL5A-40kHz/frf.1640559938622.csv | 2.00e+04 Hz | len 2047 | gap 797
# Q-V-RL5A-40kHz/frf.1640559939422.csv | 2.00e+04 Hz | len 2047 | gap 800
# Q-V-RL5A-40kHz/frf.1640559940219.csv | 2.00e+04 Hz | len 2047 | gap 797
# Q-V-RL5A-40kHz/frf.1640559941033.csv | 2.00e+04 Hz | len 2047 | gap 814
# Q-V-RL5A-40kHz/frf.1640559941828.csv | 2.00e+04 Hz | len 2047 | gap 795
# Q-V-RL5A-40kHz/frf.1640559942614.csv | 2.00e+04 Hz | len 2047 | gap 786
# Q-V-RL5A-40kHz/frf.1640559943421.csv | 2.00e+04 Hz | len 2047 | gap 807
# Q-V-RL5A-40kHz/frf.1640559944255.csv | 2.00e+04 Hz | len 2047 | gap 834
#
# Q-V-RL5A-50kHz/frf.1640560213313.csv | 2.50e+04 Hz | len 2047 | gap NA
# Q-V-RL5A-50kHz/frf.1640560216952.csv | 2.50e+04 Hz | len 2047 | gap 3639
# Q-V-RL5A-50kHz/frf.1640560220653.csv | 2.50e+04 Hz | len 2047 | gap 3701
# Q-V-RL5A-50kHz/frf.1640560224362.csv | 2.50e+04 Hz | len 2047 | gap 3709
# Q-V-RL5A-50kHz/frf.1640560228045.csv | 2.50e+04 Hz | len 2047 | gap 3683
# Q-V-RL5A-50kHz/frf.1640560231693.csv | 2.50e+04 Hz | len 2047 | gap 3648
# Q-V-RL5A-50kHz/frf.1640560235436.csv | 2.50e+04 Hz | len 2047 | gap 3743
# Q-V-RL5A-50kHz/frf.1640560239165.csv | 2.50e+04 Hz | len 2047 | gap 3729
# Q-V-RL5A-50kHz/frf.1640560242878.csv | 2.50e+04 Hz | len 2047 | gap 3713
# Q-V-RL5A-50kHz/frf.1640560245463.csv | 2.50e+04 Hz | len 2047 | gap 2585

# %%
for data_directory in data_directories:
    #print(data_directory)
    vf.plot_plant(data_directory, R=110E-3, L=120E-6, plot_phase=False, mag_label='measured')
