# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')
import vesc_frf as vf

# %%
data_directories = ['Q-V-RL5A-10kHz-9CTB',
                    'Q-V-RL5A-20kHz-9CTB',
                    'Q-V-RL5A-30kHz-9CTB',
                    'Q-V-RL5A-40kHz-9CTB',
                    'Q-V-RL5A-50kHz-9CTB']

for data_directory in data_directories:
    vf.data_report(vf.get_file_list(data_directory))
    print()
# Out:
# Q-V-RL5A-10kHz-9CTB/frf.1640560726801.csv | 5.00e+03 Hz | len 2047 | gap NA
# Q-V-RL5A-10kHz-9CTB/frf.1640560727420.csv | 5.00e+03 Hz | len 2047 | gap 619
# Q-V-RL5A-10kHz-9CTB/frf.1640560728017.csv | 5.00e+03 Hz | len 2047 | gap 597
# Q-V-RL5A-10kHz-9CTB/frf.1640560728629.csv | 5.00e+03 Hz | len 2047 | gap 612
# Q-V-RL5A-10kHz-9CTB/frf.1640560729249.csv | 5.00e+03 Hz | len 2047 | gap 620
# Q-V-RL5A-10kHz-9CTB/frf.1640560729864.csv | 5.00e+03 Hz | len 2047 | gap 615
# Q-V-RL5A-10kHz-9CTB/frf.1640560730470.csv | 5.00e+03 Hz | len 2047 | gap 606
# Q-V-RL5A-10kHz-9CTB/frf.1640560731081.csv | 5.00e+03 Hz | len 2047 | gap 611
# Q-V-RL5A-10kHz-9CTB/frf.1640560731682.csv | 5.00e+03 Hz | len 2047 | gap 601
# Q-V-RL5A-10kHz-9CTB/frf.1640560732301.csv | 5.00e+03 Hz | len 2047 | gap 619
#
# Q-V-RL5A-20kHz-9CTB/frf.1640561285148.csv | 1.00e+04 Hz | len 2047 | gap NA
# Q-V-RL5A-20kHz-9CTB/frf.1640561285592.csv | 1.00e+04 Hz | len 2047 | gap 444
# ...

# %%
for data_directory in data_directories:
    #print(data_directory)
    vf.plot_plant(data_directory, R=110E-3, L=120E-6, 
                  plot_phase=False, mag_label='measured', title=data_directory)
